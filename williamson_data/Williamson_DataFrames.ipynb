# %%
#import pandas to create usable dataframes with all the data
import pandas as pd

# %%
williamson_grapi = pd.read_csv("williamson_GRAPI.csv",sep='\t')

# %%
williamson_grapi.dropna(how = "any")
# Out:
#   GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME (GRAPI)    2007    2008  \
# 0  Occupied units paying rent (excluding units wh...      32,563  34,171
# 1                             Less than 15.0 percent        4005    3793
# 2                               15.0 to 19.9 percent        4624    5536
# 3                               20.0 to 24.9 percent        5145    5502
# 4                               25.0 to 29.9 percent        3908    4852
# 5                               30.0 to 34.9 percent        3093    3349
# 6                               35.0 percent or more       11788   11140
# 8                                       Not computed       1,162   1,995
#
#      2009    2010    2011    2012    2013    2014    2015    2016
# 0  37,546  50,023  51,082  50,419  46,841  51,559  49,419   53,11
# 1    4468    5,94   4,428   7,203   5,519   6,132   4,386   6,545
# 2    4581   7,828   8,098   7,633   5,782   6,329    8,97    7,39
# ...

# %%
williamson_gross_rent = pd.read_csv("williamson_gross_rent.csv", sep = "\t")

# %%
williamson_gross_rent.dropna(how="any")
# Out:
#                     GROSS RENT    2007    2008    2009    2010    2011  \
# 0   Occupied units paying rent  32,855  34,247  37,882  50,674  51,441
# 1               Less than $200     197      34     189     153     129
# 2                 $200 to $299     559     582     189     398     421
# 3                 $300 to $499     756     685     303   1,105     721
# 4                 $500 or less    1512    1301     681   1,656   1,271
# 5                 $500 to $749    5487    4555    5038   9,144   8,951
# 6                 $750 to $999   11335   11952   13221  16,541  15,642
# 7                 $500 to $999   16822   16507   18259  25,685  24,593
# 8             $1,000 to $1,499   11532   12808    6829  16,972  19,685
# 9               $1,500 or more    3056    4349     867   6,361   5,892
# 10            Median (dollars)     963     929   1,002     970     998
# 12                No rent paid     870   1,919     860   1,467     626
#
#       2012    2013    2014    2015    2016
# ...

# %%
williamson_housing = pd.read_csv("williamson_housing.csv", sep = "\t")

# %%
williamson_housing.dropna(how = "any")
# Out:
#         HOUSING OCCUPANCY     2007     2008     2009     2010     2011  \
# 0     Total housing units  131,173  136,951  142,237  163,264  168,523
# 1  Occupied housing units  121,899   93.30%   93.50%  152,739  156,738
# 2    Vacant housing units    9,274    6.70%    6.50%   10,525   11,785
# 3  Homeowner vacancy rate      2.2      1.7      1.4      1.6      1.4
# 4     Rental vacancy rate      4.1      6.9      8.1        7      5.5
#
#       2012     2013     2014     2015     2016
# 0  167,203  171,144  175,673  181,000  186,975
# 1  156,215  161,887  164,805  170,987  173,125
# 2   10,988    9,257   10,868   10,013   13,850
# 3      2.1      2.1      0.6      1.2      1.8
# 4      5.2      4.6      8.2      5.3      8.6

# %%
williamson_mortgage_status = pd.read_csv("williamson_mortage_status.csv")

# %%
williamson_mortgage_status.drop(williamson_mortgage_status.index[3:])
# Out:
#                     MORTGAGE STATUS    2007    2008    2009     2010     2011  \
# 0              Owner-occupied units  88,174  91,625  94,239  100,598  104,671
# 1     Housing units with a mortgage   70451   73025   74166   79,934   80,318
# 2  Housing units without a mortgage  17,723  18,600  20,073   20,664   24,353
#
#       2012     2013     2014     2015     2016  Unnamed: 11  Unnamed: 12  \
# 0  104,293  112,744  110,714  119,375  117,637          NaN          NaN
# 1   80,830   82,526   80,534   86,936   87,071          NaN          NaN
# 2   23,463   30,218   30,180   32,439   30,566          NaN          NaN
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN

# %%
williamson_smocapi = pd.read_csv("williamson_SMOCAPI.csv", sep = "\t")

# %%
williamson_smocapi.dropna(how = "any")
# Out:
#    SELECTED MONTHLY OWNER COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME (SMOCAPI)  \
# 0   Housing units with a mortgage (excluding units...
# 1                              Less than 20.0 percent
# 2                                20.0 to 24.9 percent
# 3                                25.0 to 29.9 percent
# 4                                30.0 to 34.9 percent
# 5                                35.0 percent or more
# 7                                        Not computed
# 9   Housing unit without a mortgage (excluding uni...
# 10                             Less than 10.0 percent
# 11                               10.0 to 14.9 percent
# 12                               15.0 to 19.9 percent
# 13                               20.0 to 24.9 percent
# 14                               25.0 to 29.9 percent
# 15                               30.0 to 34.9 percent
# 16                               35.0 percent or more
# 18                                       Not computed
#
# ...

# %%
williamson_tenure = pd.read_csv("williamson_tenure.csv", sep = "\t")

# %%
williamson_tenure.dropna(how = "any")
# Out:
#            HOUSING TENURE     2007     2008     2009     2010     2011  \
# 0  Occupied housing units  121,899  127,791  132,981  152,739  156,738
# 1          Owner-occupied    88133    91626    94284  100,598  104,671
# 2         Renter-occupied   33,766   36,165   38,697   52,141   52,067
#
#       2012     2013     2014     2015     2016
# 0  156,215  161,887  164,805  170,987  173,125
# 1  104,293  112,744  110,714  119,375  117,637
# 2   51,922   49,143   54,091   51,612   55,488

# %%
williamson_value = pd.read_csv("williamson_value.csv")

# %%
williamson_value.drop(williamson_value.index[10:])
# Out:
#                   VALUE     2007     2008     2009     2010     2011     2012  \
# 0  Owner-occupied units   88,174   91,625   94,239  100,598  104,671  104,293
# 1     Less than $50,000    2.00%    2.80%    2.90%    3,893    3,541    3,281
# 2    $50,000 to $99,999    6.90%    6.60%    6.70%    5,020    6,056    5,492
# 3  $100,000 to $149,999   28.40%   22.60%   24.00%   25,226   24,827   24,574
# 4  $150,000 to $199,999   28.40%   28.40%   27.10%   26,508   28,556   27,683
# 5  $200,000 to $299,999   22.50%   24.90%   25.60%   26,565   26,446   30,458
# 6  $300,000 to $499,999   10.30%   12.30%   10.60%   11,277   13,437   10,685
# 7  $500,000 to $999,999    1.10%    2.00%    2.70%    1,891    1,632    1,797
# 8    $1,000,000 or more    0.30%    0.40%    0.50%      218      176      323
# 9      Median (dollars)  176,700  178,400  175,300  175,100  176,500  179,600
#
#       2013     2014     2015     2016  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# ...
